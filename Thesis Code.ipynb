# %%
### Data preprocessing

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re
from collections import Counter
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import matplotlib.pyplot as plt

# %%
# load Aldi
df = pd.read_csv('/Users/esthercorcoran/Desktop/Thesis/Aldi/aldi_dataset.csv')


# load Lidl
df = pd.read_csv('/Users/esthercorcoran/Desktop/Thesis/Lidl/lidl_dataset.csv')

# %%
df
# Out:
#       Review Number                                        Review Text Store
# 0                 1  Aldi's generally receives positive reviews for...  Aldi
# 1                 2  Well laid out shop. Good selection of  foods, ...  Aldi
# 2                 3  Good store. The problem with some of these dis...  Aldi
# 3                 4  Super-fantastic!!!! 💖💕💞💖💕💞\nVery good products...  Aldi
# 4                 5  The quality of meat at Aldi doesn't looks well...  Aldi
# ...             ...                                                ...   ...
# 4731            324                                 Very very nice....  Aldi
# 4732            325                                 Nice place to shop  Aldi
# 4733            326                Good  value  shame about the queasy  Aldi
# 4734            327                     The tellers are very rude here  Aldi
# 4735            328                      Good convieniance and produce  Aldi
#
# [4736 rows x 3 columns]

# %%
### initial organisation 

df['Review Number'] = range(1, len(df) + 1)
df.set_index('Review Number', inplace=True)

# %%
### data cleaning

# %%
# Preprocessing and tokenizing the text data
def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Split text into words
    words = text.split()
    # Remove stop words
    words = [word for word in words if word not in ENGLISH_STOP_WORDS]
    return words

df['Processed Text'] = df['Review Text'].apply(preprocess_text)

# %%
### sentiment analysis

# %%
analyzer = SentimentIntensityAnalyzer()

def get_vader_sentiment(text):
    sentiment_dict = analyzer.polarity_scores(text)
    compound_score = sentiment_dict['compound']
    if compound_score >= 0.05:
        return 'positive', compound_score
    elif compound_score <= -0.05:
        return 'negative', compound_score
    else:
        return 'neutral', compound_score

df['Sentiment Label'], df['Sentiment Score'] = zip(*df['Review Text'].apply(get_vader_sentiment))

# %%
### label distribution

# %%
Label_Distribution = df['Sentiment Label'].value_counts()
print(Label_Distribution)
# Out:
# Sentiment Label
# positive    3668
# neutral      637
# negative     431
# Name: count, dtype: int64

# %%
### word frequency analysis

# %%
word_list = df['Processed Text'].sum()
word_freq = Counter(word_list)

word_freq
# Out:
# Counter({'good': 1331,
#          'great': 1312,
#          'staff': 1004,
#          'aldi': 898,
#          'shop': 749,
#          'store': 582,
#          'prices': 512,
#          'value': 397,
#          'friendly': 388,
#          'nice': 386,
#          'shopping': 375,
#          'parking': 374,
#          'place': 334,
#          'products': 315,
#          'food': 301,
#          'helpful': 274,
#          'quality': 262,
#          'love': 241,
#          'service': 220,
#          'cheap': 217,
#          'selection': 213,
#          'price': 210,
#          'like': 208,
#          'best': 189,
#          'clean': 186,
#          'excellent': 173,
#          'need': 168,
#          'just': 159,
#          'supermarket': 158,
#          'stocked': 155,
#          'items': 139,
#          'time': 139,
#          'busy': 133,
#          'lovely': 133,
#          'fresh': 132,
#          'really': 127,
#          'lidl': 123,
#          'stock': 121,
#          'easy': 121,
#          'dont': 119,
#          'big': 118,
#          'money': 116,
#          'variety': 116,
#          'people': 116,
#          'range': 105,
#          'better': 97,
#          'free': 93,
#          'customer': 92,
#          'lots': 87,
#          'bit': 87,
#          'plenty': 87,
#          'car': 84,
#          'experience': 84,
#          'lot': 82,
#          'stores': 80,
#          'tills': 80,
#          'buy': 79,
#          'got': 79,
#          'new': 79,
#          'groceries': 78,
#          'fruit': 78,
#          'till': 78,
#          'things': 75,
#          'goods': 75,
#          'reasonable': 74,
#          'choice': 74,
#          'open': 72,
#          'special': 72,
#          'location': 72,
#          'long': 71,
#          'park': 71,
#          'shelves': 71,
#          'customers': 71,
#          'quick': 70,
#          'small': 70,
#          'pleasant': 68,
#          'grocery': 67,
#          'produce': 66,
#          'stuff': 66,
#          'times': 65,
#          'aldis': 64,
#          'super': 64,
#          'low': 63,
#          'weekly': 62,
#          'offers': 62,
#          'ok': 61,
#          'veg': 59,
#          'today': 59,
#          'bargains': 59,
#          'dublin': 58,
#          'day': 58,
#          'deals': 58,
#          'quite': 58,
#          'usual': 56,
#          'check': 56,
#          'cheaper': 55,
#          'handy': 54,
#          'checkout': 54,
#          'local': 53,
#          'vegetables': 52,
#          'amazing': 52,
#          'way': 52,
#          'recommend': 51,
#          'efficient': 51,
#          'needed': 51,
#          'favourite': 51,
#          'available': 50,
#          'queues': 50,
#          'say': 50,
#          'meat': 49,
#          'know': 49,
#          'use': 48,
#          'looking': 48,
#          'going': 48,
#          'affordable': 47,
#          'im': 47,
#          'want': 47,
#          'little': 47,
#          'went': 47,
#          'wide': 46,
#          'needs': 46,
#          'product': 46,
#          'security': 45,
#          'spacious': 44,
#          'space': 44,
#          'work': 44,
#          'didnt': 43,
#          'help': 42,
#          'area': 42,
#          'queue': 42,
#          'week': 41,
#          'fast': 41,
#          'brilliant': 41,
#          'rude': 41,
#          'large': 41,
#          'fantastic': 41,
#          'bad': 40,
#          'visit': 40,
#          'usually': 40,
#          'happy': 39,
#          'home': 39,
#          'layout': 39,
#          'tidy': 38,
#          'checkouts': 37,
#          'poor': 37,
#          'tesco': 37,
#          'shops': 36,
#          'middle': 34,
#          'convenient': 34,
#          'manager': 34,
#          'think': 34,
#          'underground': 34,
#          'ireland': 33,
#          'make': 33,
#          'supermarkets': 33,
#          'trolley': 33,
#          'options': 32,
#          'foods': 32,
#          'right': 32,
#          'irish': 31,
#          'ive': 31,
#          'crowded': 31,
#          'pretty': 31,
#          'told': 31,
#          'thats': 30,
#          'aisles': 30,
#          'look': 30,
#          'wine': 30,
#          'loads': 30,
#          'terenure': 30,
#          'thank': 29,
#          'section': 29,
#          'wait': 29,
#          'priced': 29,
#          'branch': 29,
#          'high': 29,
#          'buys': 28,
#          'u': 28,
#          'standard': 28,
#          'bread': 28,
#          'compared': 28,
#          'pm': 28,
#          'hard': 28,
#          'road': 27,
#          'asked': 27,
#          'does': 27,
#          'getting': 27,
#          'used': 27,
#          'worth': 27,
#          'far': 27,
#          'especially': 27,
#          'stop': 27,
#          'waiting': 27,
#          'organized': 27,
#          'fruits': 27,
#          'cashier': 27,
#          'different': 27,
#          'doesnt': 26,
#          'definitely': 26,
#          'date': 26,
#          'did': 25,
#          'stars': 25,
#          'close': 25,
#          'cheapest': 25,
#          'thing': 25,
#          'thanks': 25,
#          'years': 25,
#          'laid': 24,
#          'seen': 24,
#          'regular': 24,
#          'offer': 24,
#          'wish': 24,
#          'outside': 24,
#          'enjoy': 24,
#          'normal': 24,
#          'said': 24,
#          'bakery': 24,
#          'number': 24,
#          'inside': 23,
#          'self': 23,
#          'sell': 23,
#          'extremely': 23,
#          'grand': 23,
#          'centre': 23,
#          'fine': 23,
#          'old': 23,
#          'near': 23,
#          'left': 23,
#          'floor': 23,
#          'decent': 23,
#          'huge': 23,
#          'street': 23,
#          'carpark': 23,
#          'minutes': 23,
#          'run': 23,
#          'sure': 22,
#          'come': 22,
#          'chicken': 22,
#          'city': 22,
#          'pay': 22,
#          'entrance': 22,
#          'hours': 22,
#          'id': 22,
#          'brand': 22,
#          'item': 22,
#          'overall': 22,
#          'wont': 22,
#          'sold': 21,
#          'away': 21,
#          'sunday': 21,
#          'packed': 21,
#          'wanted': 21,
#          'feel': 21,
#          'covid': 21,
#          'ask': 21,
#          'problem': 20,
#          'polite': 20,
#          'having': 20,
#          'expect': 20,
#          'reasonably': 20,
#          'cheerful': 20,
#          'bright': 20,
#          'bray': 20,
#          'meats': 19,
#          'discount': 19,
#          'member': 19,
#          'spaces': 19,
#          'doing': 19,
#          'gone': 19,
#          'household': 19,
#          'opened': 19,
#          'quickly': 19,
#          'trolleys': 19,
#          'isle': 18,
#          'short': 18,
#          'aisle': 18,
#          'expensive': 18,
#          'cost': 18,
#          'morning': 18,
#          'bought': 18,
#          'theres': 18,
#          'opening': 18,
#          'plus': 18,
#          'quiet': 18,
#          'building': 18,
#          'bags': 18,
#          'brands': 18,
#          'coolock': 18,
#          'evening': 18,
#          'highly': 17,
#          'days': 17,
#          'specials': 17,
#          'management': 17,
#          'trying': 17,
#          'youre': 17,
#          'dirty': 17,
#          'makes': 17,
#          'located': 17,
#          'daily': 17,
#          'competitive': 17,
#          'n': 17,
#          'ample': 17,
#          'safe': 17,
#          'perfect': 17,
#          'market': 17,
#          'cash': 17,
#          'weeks': 17,
#          'closed': 16,
#          'working': 16,
#          'pack': 16,
#          'tell': 16,
#          'star': 16,
#          'distancing': 16,
#          'guy': 16,
#          'door': 16,
#          'pleasure': 16,
#          'center': 16,
#          'wines': 16,
#          'bargain': 16,
#          'particular': 16,
#          'social': 16,
#          'prefer': 16,
#          'cashiers': 16,
#          'try': 16,
#          'euro': 16,
#          'came': 16,
#          'christmas': 16,
#          'limited': 16,
#          'generally': 15,
#          'walk': 15,
#          's': 15,
#          'absolutely': 15,
#          'eat': 15,
#          'live': 15,
#          'end': 15,
#          'half': 15,
#          'understand': 15,
#          'fair': 15,
#          'year': 15,
#          'tight': 15,
#          'baby': 15,
#          'organised': 15,
#          'rush': 15,
#          'bag': 15,
#          'bigger': 15,
#          'wouldnt': 15,
#          'family': 15,
#          'disappointed': 15,
#          'wrong': 15,
#          'change': 15,
#          'ashbourne': 15,
#          'shoppers': 14,
#          'helpfull': 14,
#          'looked': 14,
#          'extra': 14,
#          'save': 14,
#          'care': 14,
#          'review': 14,
#          'general': 14,
#          'beautiful': 14,
#          'packing': 14,
#          'wonderful': 14,
#          'house': 14,
#          'kind': 14,
#          'isnt': 14,
#          'lines': 14,
#          'luas': 14,
#          'beat': 14,
#          'sandyford': 14,
#          'frozen': 13,
#          'tools': 13,
#          'spot': 13,
#          'making': 13,
#          'probably': 13,
#          'main': 13,
#          'disabled': 13,
#          'card': 13,
#          'milk': 13,
#          'felt': 13,
#          'missing': 13,
#          'access': 13,
#          'budget': 13,
#          'rest': 13,
#          'messy': 13,
#          'basket': 13,
#          'unfortunately': 13,
#          'spend': 13,
#          'size': 13,
#          'clothes': 13,
#          'able': 13,
#          'recently': 13,
#          'theyre': 12,
#          'looks': 12,
#          'coming': 12,
#          'vegan': 12,
#          'choose': 12,
#          'plastic': 12,
#          'terrible': 12,
#          'hope': 12,
#          'deal': 12,
#          'despite': 12,
#          'masks': 12,
#          'shopped': 12,
#          'leave': 12,
#          'early': 12,
#          'cool': 12,
#          'alot': 12,
#          'town': 12,
#          'smaller': 12,
#          'places': 12,
#          'professional': 12,
#          'person': 12,
#          'roof': 12,
#          'shelf': 12,
#          'issue': 12,
#          'wasnt': 12,
#          'buying': 12,
#          'basic': 12,
#          'average': 12,
#          'life': 12,
#          'bus': 12,
#          'th': 12,
#          'dunnes': 12,
#          'slow': 12,
#          'sallynoggin': 12,
#          'ready': 11,
#          'popular': 11,
#          'east': 11,
#          'particularly': 11,
#          'willing': 11,
#          'fan': 11,
#          'facilities': 11,
#          'fact': 11,
#          'man': 11,
#          'reason': 11,
#          'wearing': 11,
#          'veggies': 11,
#          'staffs': 11,
#          'queuing': 11,
#          'line': 11,
#          'maybe': 11,
#          'problems': 11,
#          'traffic': 11,
#          'receipt': 11,
#          'recommended': 11,
#          'untidy': 11,
#          'sells': 11,
#          'baskets': 11,
#          'lost': 11,
#          'levels': 11,
#          'savings': 11,
#          'tasty': 10,
#          'young': 10,
#          'lady': 10,
#          'nearby': 10,
#          'fully': 10,
#          'anymore': 10,
#          'wall': 10,
#          'control': 10,
#          'saturday': 10,
#          'start': 10,
#          'tho': 10,
#          'impressed': 10,
#          'let': 10,
#          'past': 10,
#          'competition': 10,
#          'typical': 10,
#          'lack': 10,
#          'bring': 10,
#          'return': 10,
#          'mins': 10,
#          'accessible': 10,
#          'nearly': 10,
#          'sale': 10,
#          'everyday': 10,
#          'second': 10,
#          'longer': 10,
#          'shelfs': 10,
#          'shame': 10,
#          'fault': 10,
#          'regularly': 10,
#          'changed': 10,
#          'cheese': 10,
#          'pity': 10,
#          'walking': 10,
#          'beer': 10,
#          'started': 10,
#          'interesting': 10,
#          'larger': 10,
#          'took': 10,
#          'box': 10,
#          'flowers': 10,
#          'essential': 10,
#          'choices': 10,
#          'beef': 10,
#          'health': 10,
#          'loved': 10,
#          'favorite': 10,
#          'isles': 10,
#          'meals': 10,
#          'santry': 10,
#          'soon': 9,
#          'st': 9,
#          'pocket': 9,
#          'outs': 9,
#          'express': 9,
#          'escalators': 9,
#          'dates': 9,
#          'phone': 9,
#          'toilet': 9,
#          'kids': 9,
#          'competitors': 9,
#          'closing': 9,
#          'healthy': 9,
#          'drink': 9,
#          'alright': 9,
#          'woman': 9,
#          'twice': 9,
#          'couple': 9,
#          'stand': 9,
#          'garden': 9,
#          'members': 9,
#          'parnell': 9,
#          'okay': 9,
#          'non': 9,
#          'plants': 9,
#          'exactly': 9,
#          'certain': 9,
#          'checking': 9,
#          'light': 9,
#          'says': 9,
#          'dairy': 9,
#          'expected': 9,
#          'mulhuddart': 9,
#          'fairly': 8,
#          'bits': 8,
#          'unhelpful': 8,
#          'head': 8,
#          'visiting': 8,
#          'weekend': 8,
#          'attention': 8,
#          'guard': 8,
#          'sorry': 8,
#          'smile': 8,
#          'water': 8,
#          'ground': 8,
#          'managed': 8,
#          'ago': 8,
#          'exit': 8,
#          'grab': 8,
#          'late': 8,
#          'months': 8,
#          'pick': 8,
#          'served': 8,
#          'pleased': 8,
#          'absolute': 8,
#          'biggest': 8,
#          'gardening': 8,
#          'nicest': 8,
#          'slightly': 8,
#          'option': 8,
#          'shopper': 8,
#          'disappointing': 8,
#          'services': 8,
#          'means': 8,
#          'locations': 8,
#          'nicer': 8,
#          'complaint': 8,
#          'job': 8,
#          'chain': 8,
#          'ill': 8,
#          'friend': 8,
#          'paying': 8,
#          'girl': 8,
#          'ones': 8,
#          'similar': 8,
#          'difficult': 8,
#          'mask': 8,
#          'blanchardstown': 8,
#          'x': 8,
#          'hate': 8,
#          'team': 8,
#          'lay': 8,
#          'l': 8,
#          'que': 8,
#          'nicely': 8,
#          'surprised': 8,
#          'mess': 8,
#          'thursday': 8,
#          'face': 8,
#          'wheelchair': 8,
#          'round': 8,
#          'fab': 8,
#          'tram': 8,
#          'airy': 8,
#          'issues': 8,
#          'navigate': 8,
#          'appreciate': 7,
#          'delicious': 7,
#          'alway': 7,
#          'discounts': 7,
#          'add': 7,
#          'careful': 7,
#          'cars': 7,
#          'stocks': 7,
#          'whats': 7,
#          'scanning': 7,
#          'opinion': 7,
#          'bike': 7,
#          'given': 7,
#          'crowd': 7,
#          'situation': 7,
#          'central': 7,
#          'appreciated': 7,
#          'lower': 7,
#          'purchase': 7,
#          'refund': 7,
#          'gave': 7,
#          'assistant': 7,
#          'german': 7,
#          'reply': 7,
#          'easily': 7,
#          'drinks': 7,
#          'modern': 7,
#          'current': 7,
#          'chocolate': 7,
#          'example': 7,
#          'massive': 7,
#          'annoying': 7,
#          'fun': 7,
#          'branches': 7,
#          'happened': 7,
#          'packaging': 7,
#          'avoid': 7,
#          'peak': 7,
#          'including': 7,
#          'cause': 7,
#          'totally': 7,
#          'giving': 7,
#          'goes': 7,
#          'conveniently': 7,
#          'showed': 7,
#          'employees': 7,
#          'yeah': 7,
#          'feeling': 7,
#          'keeping': 7,
#          'instead': 7,
#          'downside': 7,
#          'terms': 7,
#          'assortment': 7,
#          'worst': 7,
#          'maintained': 7,
#          'stuffs': 7,
#          'ques': 7,
#          'awesome': 7,
#          'renovated': 7,
#          'clearly': 7,
#          'hour': 7,
#          'courteous': 7,
#          'gluten': 7,
#          'onions': 7,
#          'eye': 7,
#          'afternoon': 7,
#          'bargins': 7,
#          'seriously': 7,
#          'pricing': 7,
#          'unfriendly': 7,
#          'welcoming': 7,
#          'designed': 7,
#          'kept': 7,
#          'restocking': 7,
#          'older': 7,
#          'rarely': 7,
#          'essentials': 7,
#          'vegetarian': 7,
#          'village': 7,
#          'positive': 6,
#          'retailers': 6,
#          'improved': 6,
#          'walked': 6,
#          'organic': 6,
#          'sort': 6,
#          'attitude': 6,
#          'personal': 6,
#          'racks': 6,
#          'feels': 6,
#          'stuck': 6,
#          'coffee': 6,
#          'takes': 6,
#          'locate': 6,
#          'boxes': 6,
#          'enjoyed': 6,
#          'notice': 6,
#          'built': 6,
#          'e': 6,
#          'clamped': 6,
#          'hassle': 6,
#          'constantly': 6,
#          'unlike': 6,
#          'level': 6,
#          'room': 6,
#          'site': 6,
#          'wellstocked': 6,
#          'superb': 6,
#          'indoor': 6,
#          'lacking': 6,
#          'gets': 6,
#          'liked': 6,
#          'dear': 6,
#          'difference': 6,
#          'pizza': 6,
#          'delighted': 6,
#          'yes': 6,
#          'atmosphere': 6,
#          'cold': 6,
#          'saw': 6,
#          'knows': 6,
#          'fat': 6,
#          'sugar': 6,
#          'negative': 6,
#          'school': 6,
#          'respect': 6,
#          'taste': 6,
#          'major': 6,
#          'monday': 6,
#          'night': 6,
#          'snacks': 6,
#          'arrived': 6,
#          'mind': 6,
#          'speak': 6,
#          'talking': 6,
#          'company': 6,
#          'environment': 6,
#          'children': 6,
#          'saving': 6,
#          'leaving': 6,
#          'trollies': 6,
#          'moving': 6,
#          'comparison': 6,
#          'purchases': 6,
#          'faces': 6,
#          'relatively': 6,
#          'useful': 6,
#          'v': 6,
#          'cheep': 6,
#          'possible': 6,
#          'germany': 6,
#          'uncomfortable': 6,
#          'clear': 6,
#          'speed': 6,
#          'drive': 6,
#          'lanes': 6,
#          'fraction': 6,
#          'journey': 6,
#          'easier': 6,
#          'cream': 6,
#          'pallets': 6,
#          'refused': 6,
#          'world': 6,
#          'steaks': 6,
#          'business': 6,
#          'later': 6,
#          'fish': 6,
#          'returns': 6,
#          'welcome': 6,
#          'post': 6,
#          'charged': 6,
#          'satisfied': 5,
#          'lately': 5,
#          'wise': 5,
#          't': 5,
#          'standing': 5,
#          'future': 5,
#          'laughing': 5,
#          'families': 5,
#          'heavy': 5,
#          'freezing': 5,
#          'nightmare': 5,
#          'rathmines': 5,
#          'euros': 5,
#          'rd': 5,
#          'stunning': 5,
#          'assistance': 5,
#          'brought': 5,
#          'ease': 5,
#          'guys': 5,
#          'partner': 5,
#          'ignorant': 5,
#          'evenings': 5,
#          'class': 5,
#          'hi': 5,
#          'corner': 5,
#          'supplies': 5,
#          'compare': 5,
#          'england': 5,
#          'almond': 5,
#          'toilets': 5,
#          'red': 5,
#          'actually': 5,
#          'checked': 5,
#          'purchased': 5,
#          'egg': 5,
#          'broken': 5,
#          'package': 5,
#          'mince': 5,
#          'finding': 5,
#          'month': 5,
#          'noticed': 5,
#          'joke': 5,
#          'selections': 5,
#          'enter': 5,
#          'unpleasant': 5,
#          'workers': 5,
#          'finally': 5,
#          'yesterday': 5,
#          'offering': 5,
#          'suitable': 5,
#          'point': 5,
#          'vegetable': 5,
#          'alcohol': 5,
#          'friday': 5,
#          'true': 5,
#          'seasonal': 5,
#          'apart': 5,
#          'wallet': 5,
#          'specially': 5,
#          'treated': 5,
#          'normally': 5,
#          'havent': 5,
#          'daughter': 5,
#          'treat': 5,
#          'reliable': 5,
#          'dog': 5,
#          'bananas': 5,
#          'chat': 5,
#          'aldl': 5,
#          'tool': 5,
#          'mainly': 5,
#          'complete': 5,
#          'trips': 5,
#          'packet': 5,
#          'tree': 5,
#          'cooked': 5,
#          'counter': 5,
#          'asking': 5,
#          'dead': 5,
#          'hands': 5,
#          'unbeatable': 5,
#          'spent': 5,
#          'lunch': 5,
#          'dinner': 5,
#          'consider': 5,
#          'narrow': 5,
#          'simple': 5,
#          'varieties': 5,
#          'rice': 5,
#          'language': 5,
#          'display': 5,
#          'breads': 5,
#          'approx': 5,
#          'child': 5,
#          'rolls': 5,
#          'contact': 5,
#          'awkward': 5,
#          'weekends': 5,
#          'thought': 5,
#          'ideal': 5,
#          'wear': 5,
#          'awful': 5,
#          'english': 5,
#          'watch': 5,
#          'supply': 5,
#          'calm': 5,
#          'rotten': 5,
#          'tin': 5,
#          'meal': 5,
#          'sign': 5,
#          'list': 5,
#          'alternative': 5,
#          'branded': 5,
#          'hand': 5,
#          'd': 5,
#          'availability': 5,
#          'trip': 5,
#          'europe': 5,
#          'stay': 5,
#          'youd': 5,
#          'single': 5,
#          'standards': 5,
#          'areas': 5,
#          'type': 5,
#          'yellow': 5,
#          'enjoyable': 5,
#          'known': 5,
#          'muffins': 5,
#          'address': 5,
#          'stillorgan': 5,
#          'south': 5,
#          'cheers': 5,
#          'toys': 5,
#          'staffed': 4,
#          'incredibly': 4,
#          'b': 4,
#          'opposite': 4,
#          'lidls': 4,
#          'female': 4,
#          'helping': 4,
#          'sized': 4,
#          'handed': 4,
#          'robin': 4,
#          'stood': 4,
#          'lights': 4,
#          'original': 4,
#          'station': 4,
#          'bridge': 4,
#          'taken': 4,
#          'proper': 4,
#          'sweets': 4,
#          'basement': 4,
#          'spoke': 4,
#          'using': 4,
#          'spots': 4,
#          'clamping': 4,
#          'satisfaction': 4,
#          'lads': 4,
#          'ye': 4,
#          'hello': 4,
#          'polish': 4,
#          'pandemic': 4,
#          'distance': 4,
#          'f': 4,
#          'living': 4,
#          'country': 4,
#          'miss': 4,
#          'present': 4,
#          'lucky': 4,
#          'score': 4,
#          'traditional': 4,
#          'surprisingly': 4,
#          'markets': 4,
#          'kinds': 4,
#          'prior': 4,
#          'floors': 4,
#          'effective': 4,
#          'transport': 4,
#          'rate': 4,
#          'black': 4,
#          'filled': 4,
#          'sufficient': 4,
#          'chance': 4,
#          'shocked': 4,
#          'rudeness': 4,
#          'bar': 4,
#          'visited': 4,
#          'running': 4,
#          'quicker': 4,
#          'higher': 4,
#          'voucher': 4,
#          'underneath': 4,
#          'cents': 4,
#          'measures': 4,
#          'tried': 4,
#          'putting': 4,
#          'explanation': 4,
#          'chaotic': 4,
#          'cooking': 4,
#          'yogurt': 4,
#          'm': 4,
#          'provide': 4,
#          'bottle': 4,
#          'heart': 4,
#          'sick': 4,
#          'oclock': 4,
#          'percent': 4,
#          'restocked': 4,
#          'furniture': 4,
#          'white': 4,
#          'supervalu': 4,
#          'hygiene': 4,
#          'various': 4,
#          'ppl': 4,
#          'basics': 4,
#          'shown': 4,
#          'hadnt': 4,
#          'michel': 4,
#          'spotless': 4,
#          'badly': 4,
#          'pain': 4,
#          'raw': 4,
#          'mention': 4,
#          'fabulous': 4,
#          'opens': 4,
#          'disorganized': 4,
#          'costumer': 4,
#          'ur': 4,
#          'plan': 4,
#          'arent': 4,
#          'speedy': 4,
#          'moment': 4,
#          'real': 4,
#          ...})

# %%
### remove low freq words

# %%
low_stop_words = [word for word, freq in word_freq.items() if freq <= 10]
low_stop_words = set(low_stop_words)

# %%
low_stop_words
# Out:
# {'families',
#  'lucky',
#  'die',
#  'facing',
#  'manoeuvre',
#  'fruitveg',
#  'independent',
#  'posted',
#  'exploitation',
#  'sparkling',
#  'leaving',
#  'comaderie',
#  'listen',
#  'onestop',
#  'cake',
#  'customary',
#  'holidays',
#  'spaceous',
#  'unknown',
#  'medical',
#  'shelfsover',
#  'including',
#  'follows',
#  'exiting',
#  'lessthe',
#  'checked',
#  'updating',
#  'rugsack',
#  'verity',
#  'firepits',
#  'polish',
#  'healthy',
#  'cardsdriver',
#  'wafers',
#  'browse',
#  'lov',
#  'newspapers',
#  'sandyfordstillorgan',
#  'causes',
#  'starving',
#  'planter',
#  'wellkept',
#  'pull',
#  'lamb',
#  'scented',
#  'insist',
#  'loving',
#  'forming',
#  'ridiculous',
#  'dayi',
#  'monitor',
#  'knocked',
#  'jim',
#  'leaping',
#  'vegeta',
#  'lasted',
#  'knees',
#  'overseas',
#  'matt',
#  'shampoo',
#  'vouchers',
#  'kean',
#  'piece',
#  'dump',
#  'cuz',
#  'order',
#  'hit',
#  'caused',
#  'promotion',
#  'greek',
#  'handling',
#  'reopen',
#  'cafe',
#  'width',
#  'streaked',
#  'northern',
#  'deserves',
#  'unsure',
#  'ilac',
#  'carpets',
#  'suffers',
#  'ma',
#  'fingers',
#  'prior',
#  'win',
#  'shopgreat',
#  'worse',
#  'crafts',
#  'mince',
#  'labels',
#  'slagging',
#  'purchasing',
#  'shopstuff',
#  'yo',
#  'batterys',
#  'heard',
#  'example',
#  'suppliers',
#  'frills',
#  'planned',
#  'parks',
#  'tasted',
#  'gouda',
#  'somemeat',
#  'rudest',
#  'original',
#  'complain',
#  'freezing',
#  'random',
#  'appreciate',
#  'delighted',
#  'explore',
#  'variation',
#  'butter',
#  'inother',
#  'magnetically',
#  'brown',
#  'plent',
#  'feeling',
#  'awesome',
#  'desorganized',
#  'beggars',
#  'hairy',
#  'serve',
#  'inter',
#  'chocolates',
#  'contemporary',
#  'obstruction',
#  'woman',
#  'smoke',
#  'makin',
#  'entrants',
#  'errors',
#  'itemsmore',
#  'chaotic',
#  'salad',
#  'melon',
#  'tril',
#  'aeay',
#  'rubbishes',
#  'stopped',
#  'monastery',
#  'abrupt',
#  'clonmel',
#  'kudos',
#  'hang',
#  'dissapointed',
#  'gather',
#  'phone',
#  'oddly',
#  'completely',
#  'inventory',
#  'coulx',
#  'bitta',
#  'sheds',
#  'rockbrook',
#  'helpfuldf',
#  'everytime',
#  'unhappy',
#  'cases',
#  'branded',
#  'checkpoint',
#  'sayingshe',
#  'bunched',
#  'economically',
#  'appeared',
#  'keept',
#  'nuisance',
#  'evertime',
#  'major',
#  'coin',
#  'schools',
#  'turnoff',
#  'datewas',
#  'shopfloor',
#  'conveyor',
#  'confy',
#  'gran',
#  'sd',
#  'wage',
#  'pistachio',
#  'tissues',
#  'given',
#  'gap',
#  'industries',
#  'double',
#  'assistants',
#  'beers',
#  'fianc',
#  'whats',
#  'diet',
#  'recommending',
#  'team',
#  'provides',
#  'tatoos',
#  'afternoon',
#  'homebase',
#  'transport',
#  'mick',
#  't',
#  'deliveroo',
#  'surely',
#  'ahead',
#  'photo',
#  'diving',
#  'behaviour',
#  'wall',
#  'bobs',
#  'community',
#  'supermarketopen',
#  'thnk',
#  'politeand',
#  'daughter',
#  'remains',
#  'offexpired',
#  'font',
#  'vine',
#  'prides',
#  'freezer',
#  'artisan',
#  'cartel',
#  'tooonly',
#  'veronica',
#  'communities',
#  'buz',
#  'seasons',
#  'outline',
#  'pricesmaking',
#  'speak',
#  'acceptable',
#  'pushes',
#  'packs',
#  'costed',
#  'santry',
#  'discouraging',
#  'exit',
#  'cone',
#  'blocking',
#  'gonzalez',
#  'attractions',
#  'ditto',
#  'hotel',
#  'tram',
#  'militants',
#  'betteras',
#  'walked',
#  'purchases',
#  'verse',
#  'cosmetics',
#  'diffrent',
#  'wheelchair',
#  'mentioned',
#  'coeliac',
#  'minerals',
#  'connectivity',
#  'liable',
#  'mother',
#  'literally',
#  'varieties',
#  'resulting',
#  'cut',
#  'taromat',
#  'dealth',
#  'asunday',
#  'headed',
#  'loaction',
#  'operating',
#  'lol',
#  'whilst',
#  'equally',
#  'displayed',
#  'origin',
#  'selecting',
#  'complaints',
#  'galvin',
#  'mortons',
#  'uneducated',
#  'muzzarella',
#  'lunches',
#  'sheets',
#  'porridge',
#  'q',
#  'aldl',
#  'lage',
#  'diffusers',
#  'mood',
#  'conclusion',
#  'dealz',
#  'outstanding',
#  'swap',
#  'started',
#  'pudding',
#  'sundays',
#  'chef',
#  'allways',
#  'ones',
#  'pippa',
#  'reinforce',
#  'rudeness',
#  'epespily',
#  'disease',
#  'rushing',
#  'shall',
#  'wellmanaged',
#  'timing',
#  'cooked',
#  'stroll',
#  'checkin',
#  'effective',
#  'treats',
#  'pleasentseemed',
#  'fav',
#  'conversions',
#  'glee',
#  'lean',
#  'frenidly',
#  'rummage',
#  'certainlywell',
#  'hmmm',
#  'obliged',
#  'ta',
#  'stress',
#  'displays',
#  'rounded',
#  'rudewhen',
#  'grocer',
#  'diy',
#  'disaster',
#  'ther',
#  'selction',
#  'feed',
#  'spotty',
#  'hypermarkets',
#  'blades',
#  'required',
#  'wastage',
#  'keto',
#  'metro',
#  'forgetting',
#  'impression',
#  'refund',
#  'tin',
#  'tellers',
#  'galore',
#  'shopoing',
#  'interesting',
#  'e',
#  'transactions',
#  'palm',
#  'peter',
#  'warranty',
#  'scream',
#  'eventually',
#  'evenings',
#  'depot',
#  'yey',
#  'break',
#  'speed',
#  'ethiopian',
#  'permission',
#  'reorder',
#  'drivers',
#  'bathroom',
#  'supermarketchains',
#  'cornucopia',
#  'private',
#  'accidents',
#  'fidelity',
#  'rising',
#  'suffering',
#  'pads',
#  'bladder',
#  'annoyin',
#  'relaxed',
#  'mile',
#  'markets',
#  'increasing',
#  'degree',
#  'cotton',
#  'babies',
#  'roomy',
#  'remain',
#  'treasure',
#  'heeps',
#  'cheated',
#  'lived',
#  'ithowever',
#  'goodcheap',
#  'desks',
#  'manic',
#  'greatly',
#  'carparking',
#  'eastwell',
#  'inexpensive',
#  'rubbish',
#  'askin',
#  'disappointing',
#  'noce',
#  'didl',
#  'ahhh',
#  'seeing',
#  'refrigerators',
#  'alternative',
#  'cease',
#  'peak',
#  'placeproducts',
#  'lites',
#  'stari',
#  'upholds',
#  'scary',
#  'persistent',
#  'treated',
#  'quotas',
#  'belief',
#  'du',
#  'crazy',
#  'sushi',
#  'todays',
#  'results',
#  'forever',
#  'article',
#  'cruelty',
#  'smooty',
#  'cute',
#  'station',
#  'evrytime',
#  'consumption',
#  'pandemic',
#  'diverse',
#  'females',
#  'ur',
#  'fillets',
#  'sanitisers',
#  'eye',
#  'alan',
#  'stir',
#  'lacks',
#  'hands',
#  'tried',
#  'deadly',
#  'luv',
#  'test',
#  'yards',
#  'mtre',
#  'ripoff',
#  'mushrooms',
#  'beacuse',
#  'cleanmore',
#  'founded',
#  'spotless',
#  'eclectic',
#  'reasable',
#  'circular',
#  'fresher',
#  'touching',
#  'valid',
#  'gardens',
#  'uses',
#  'weather',
#  'vaule',
#  'complaining',
#  'living',
#  'storecheckouts',
#  'delicious',
#  'restaurant',
#  'ordisinterested',
#  'hype',
#  'attitude',
#  'fainting',
#  'trolly',
#  'handled',
#  'stresses',
#  'b',
#  'soy',
#  'dynns',
#  'avlable',
#  'arent',
#  'basically',
#  'quid',
#  'guards',
#  'bonner',
#  'aldii',
#  'delivery',
#  'totaled',
#  'flavours',
#  'positive',
#  'complete',
#  'march',
#  'lidi',
#  'ield',
#  'secrurity',
#  'chocolate',
#  'lessons',
#  'hidden',
#  'address',
#  'bother',
#  'spoke',
#  'circumstances',
#  'kindest',
#  'strongly',
#  'keen',
#  'avonmore',
#  'suffered',
#  'reciept',
#  'halloween',
#  'unfair',
#  'narrow',
#  'myitem',
#  'solution',
#  'ide',
#  'interactive',
#  'pearse',
#  'arms',
#  'percent',
#  'maintenancerepair',
#  'unique',
#  'grabbin',
#  'concerned',
#  'satisfaction',
#  'unlocking',
#  'restaurants',
#  'heavily',
#  'manner',
#  'greystonesno',
#  'pulled',
#  'appreciates',
#  'messing',
#  'email',
#  'scanning',
#  'subtle',
#  'colour',
#  'prenter',
#  'tobethe',
#  'financially',
#  'sneekey',
#  'ways',
#  'reguar',
#  'criteria',
#  'fallon',
#  'period',
#  'assortment',
#  'dependant',
#  'owen',
#  'suggest',
#  'marius',
#  'dark',
#  'somethings',
#  'stocks',
#  'yummy',
#  'yr',
#  'clue',
#  'bring',
#  'risky',
#  'shape',
#  'unusual',
#  'thighs',
#  'acvording',
#  'annoying',
#  'cleaning',
#  'wasting',
#  'situation',
#  'contacted',
#  'hire',
#  'skiptheres',
#  'croissant',
#  'admire',
#  'greedy',
#  'mike',
#  'sneaking',
#  'ususl',
#  'male',
#  'capacity',
#  'loyalty',
#  'scan',
#  'cheapgood',
#  'lowerend',
#  'moden',
#  'putting',
#  'sudden',
#  'organic',
#  'itens',
#  'relativity',
#  'il',
#  'scam',
#  'giving',
#  'surpermarkets',
#  'irritated',
#  'stick',
#  'unaffordable',
#  'water',
#  'loyal',
#  'dhese',
#  'refurbished',
#  'shown',
#  'aud',
#  'canned',
#  'remaining',
#  'wa',
#  'concern',
#  'wrapped',
#  'liking',
#  'roasted',
#  'upgrading',
#  'confusingly',
#  'theirs',
#  'structure',
#  'devil',
#  'gardening',
#  'solid',
#  'annoyed',
#  'keptvery',
#  'pricec',
#  'success',
#  'upset',
#  'newstock',
#  'permits',
#  'functional',
#  'discounters',
#  'smells',
#  'clueat',
#  'anti',
#  'depends',
#  'cameras',
#  'identified',
#  'experiencelove',
#  'homebrea',
#  'supermarketi',
#  'identify',
#  'avoid',
#  'gonna',
#  'process',
#  'shoppingall',
#  'havent',
#  'pieces',
#  'btw',
#  'rid',
#  'proportion',
#  'carrbags',
#  'alternatives',
#  'apologies',
#  'inand',
#  'nov',
#  'machines',
#  'kits',
#  'diets',
#  'employee',
#  'veggie',
#  'jan',
#  'stall',
#  'synonymous',
#  'showed',
#  'botthered',
#  'lonely',
#  'platform',
#  'depending',
#  'banging',
#  'behave',
#  'gentlemen',
#  'scallops',
#  'let',
#  'egg',
#  'motel',
#  'reunited',
#  'pricesgreat',
#  'premises',
#  'em',
#  'upmarket',
#  'regularly',
#  'c',
#  'outro',
#  'grateful',
#  'aislesare',
#  'lotion',
#  'ear',
#  'games',
#  'goodforshopping',
#  'vehicles',
#  'purchase',
#  'tends',
#  'incompetent',
#  'log',
#  'survival',
#  'rathmines',
#  'pease',
#  'golden',
#  'thou',
#  'baps',
#  'exc',
#  'economical',
#  'pounding',
#  'guarantee',
#  'ups',
#  'powers',
#  'shorten',
#  'asks',
#  'disorganized',
#  'following',
#  'hygiene',
#  'replaced',
#  'nd',
#  'canal',
#  'disgraceful',
#  'appalling',
#  'eople',
#  'aldionly',
#  'yous',
#  'pricesshould',
#  'highest',
#  'tryed',
#  'appropriately',
#  'amazingly',
#  'monitoring',
#  'timetable',
#  'martha',
#  'receives',
#  'enjoyable',
#  'humor',
#  'branches',
#  'brillant',
#  'presented',
#  'boned',
#  'unchallenged',
#  'outthat',
#  'devine',
#  'stocksyoung',
#  'beaten',
#  'shoppinghardly',
#  'sequence',
#  'unlike',
#  'shoppingwhen',
#  'mineral',
#  'promoting',
#  'soon',
#  'moneygood',
#  'qualitys',
#  'greystones',
#  'frantically',
#  'trusted',
#  'lighting',
#  'modified',
#  'louis',
#  'santized',
#  'destination',
#  'jiffy',
#  'carrot',
#  'bases',
#  'kaleidoscope',
#  'late',
#  'taking',
#  'true',
#  'approximately',
#  'memeber',
#  'acknowledgement',
#  'midday',
#  'confused',
#  'pasta',
#  'bottles',
#  'pinch',
#  'reopened',
#  'gits',
#  'hardwares',
#  'aug',
#  'magical',
#  'tall',
#  'exactly',
#  'tidying',
#  'runny',
#  'type',
#  'granda',
#  'kindly',
#  'history',
#  'plesent',
#  'priority',
#  'chainsaw',
#  'bettr',
#  'jifnot',
#  'plantbased',
#  'maker',
#  'pandemicand',
#  'eating',
#  'michelle',
#  'ppl',
#  'popped',
#  'clin',
#  'seabass',
#  'picking',
#  'aldilavistha',
#  'knows',
#  'ridulous',
#  'begging',
#  'cigarettes',
#  'micro',
#  'geared',
#  'pace',
#  'neighbouring',
#  'deaf',
#  'gear',
#  'relationshipthis',
#  'fall',
#  'convenience',
#  'peed',
#  'dunces',
#  'office',
#  'purposely',
#  'munchie',
#  'isles',
#  'clamping',
#  'ideal',
#  'divine',
#  'letter',
#  'garett',
#  'itz',
#  'greece',
#  'ni',
#  'witnessed',
#  'faces',
#  'cheating',
#  'maintained',
#  'crackers',
#  'replenished',
#  'assurance',
#  'evertything',
#  'locality',
#  'boughet',
#  'refused',
#  'broken',
#  'uk',
#  'replenishing',
#  'edibles',
#  'world',
#  'senate',
#  'princess',
#  'enforce',
#  'cheers',
#  'almond',
#  'itsssss',
#  'expletives',
#  'dog',
#  'introduced',
#  'nearby',
#  'stilli',
#  'soup',
#  'significantly',
#  'approach',
#  'smooth',
#  'responsible',
#  'plastics',
#  'shot',
#  'bulk',
#  'forgot',
#  'starbucks',
#  'girls',
#  'vicroy',
#  'higgledypiggledy',
#  'junkies',
#  'pricealways',
#  'resolving',
#  'annesley',
#  'bery',
#  'panchetta',
#  'partner',
#  'resonable',
#  'honesty',
#  'massively',
#  'ev',
#  'knowledgeable',
#  'modern',
#  'country',
#  'gadgets',
#  'tone',
#  'cream',
#  'honestly',
#  'strictly',
#  'grown',
#  'knowing',
#  'germanfood',
#  'teenagers',
#  'managerment',
#  'productswell',
#  'discontinuing',
#  'storelooks',
#  'rollin',
#  'welcoming',
#  'racksfloor',
#  'issues',
#  'equipment',
#  'rains',
#  'courteous',
#  'camel',
#  'surprisingly',
#  'irregularly',
#  'frugal',
#  'hes',
#  'ambo',
#  'stereotyped',
#  'staffjust',
#  'dropping',
#  'tip',
#  'shut',
#  'cardboard',
#  'clonee',
#  'bloomer',
#  'supporting',
#  'ideas',
#  'blanchardstown',
#  'loading',
#  'protocols',
#  'impossible',
#  'cleansafe',
#  'chore',
#  'unopened',
#  'drawback',
#  'companies',
#  'agree',
#  'century',
#  'quslity',
#  'point',
#  'european',
#  'firebrigad',
#  'helping',
#  'locations',
#  'bolt',
#  'katie',
#  'relax',
#  'ingredients',
#  'preordered',
#  'procedures',
#  'mini',
#  'regrettably',
#  'kiwi',
#  'stuffs',
#  'brexit',
#  'neglected',
#  'unbelievable',
#  'inn',
#  'realized',
#  'fry',
#  'rushed',
#  'joghurt',
#  'relaxing',
#  'accused',
#  'picks',
#  'selectionstock',
#  'qualityvariety',
#  'box',
#  'helped',
#  'names',
#  'adjust',
#  'staffwine',
#  'ls',
#  'sorbets',
#  'urgently',
#  'hurt',
#  'prompted',
#  'tail',
#  'visitedextreme',
#  'arse',
#  'education',
#  'restock',
#  'garden',
#  'dairy',
#  'warned',
#  'idea',
#  'badges',
#  'shame',
#  'nearer',
#  'urgent',
#  'aldisvery',
#  'prefar',
#  'soya',
#  'irsih',
#  'multigrain',
#  'caramel',
#  'response',
#  'staffare',
#  'avenue',
#  'paint',
#  'health',
#  'managing',
#  'starting',
#  'questions',
#  'cold',
#  'goid',
#  'bridge',
#  'greatttttt',
#  'coz',
#  'bagels',
#  'stood',
#  'ad',
#  'eastwallrd',
#  'affordables',
#  'filerits',
#  'grocerys',
#  'gabrielle',
#  'funny',
#  'difficulty',
#  'minute',
#  'contemplating',
#  'maintenance',
#  'boys',
#  ...}

# %%
new_stop_words = ENGLISH_STOP_WORDS.union(set(low_stop_words))

# %%
def preprocess_text(text, new_stop_words):
    # Check if the input text is a list
    if isinstance(text, list):
        # Join the list elements into a single string
        text = ' '.join(text)
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Split text into words
    words = text.split()
    # Remove stop words
    words = [word for word in words if word not in new_stop_words]
    return words

df['Processed_Text_1'] = df['Processed Text'].apply(lambda x: preprocess_text(x, new_stop_words))

# %%
word_list1 = df['Processed_Text_1'].sum()
word_freq1 = Counter(word_list1)

word_freq1
# Out:
# Counter({'good': 1331,
#          'great': 1312,
#          'staff': 1004,
#          'aldi': 898,
#          'shop': 749,
#          'store': 582,
#          'prices': 512,
#          'value': 397,
#          'friendly': 388,
#          'nice': 386,
#          'shopping': 375,
#          'parking': 374,
#          'place': 334,
#          'products': 315,
#          'food': 301,
#          'helpful': 274,
#          'quality': 262,
#          'love': 241,
#          'service': 220,
#          'cheap': 217,
#          'selection': 213,
#          'price': 210,
#          'like': 208,
#          'best': 189,
#          'clean': 186,
#          'excellent': 173,
#          'need': 168,
#          'just': 159,
#          'supermarket': 158,
#          'stocked': 155,
#          'items': 139,
#          'time': 139,
#          'busy': 133,
#          'lovely': 133,
#          'fresh': 132,
#          'really': 127,
#          'lidl': 123,
#          'stock': 121,
#          'easy': 121,
#          'dont': 119,
#          'big': 118,
#          'money': 116,
#          'variety': 116,
#          'people': 116,
#          'range': 105,
#          'better': 97,
#          'free': 93,
#          'customer': 92,
#          'lots': 87,
#          'bit': 87,
#          'plenty': 87,
#          'car': 84,
#          'experience': 84,
#          'lot': 82,
#          'stores': 80,
#          'tills': 80,
#          'buy': 79,
#          'got': 79,
#          'new': 79,
#          'groceries': 78,
#          'fruit': 78,
#          'till': 78,
#          'things': 75,
#          'goods': 75,
#          'reasonable': 74,
#          'choice': 74,
#          'open': 72,
#          'special': 72,
#          'location': 72,
#          'long': 71,
#          'park': 71,
#          'shelves': 71,
#          'customers': 71,
#          'quick': 70,
#          'small': 70,
#          'pleasant': 68,
#          'grocery': 67,
#          'produce': 66,
#          'stuff': 66,
#          'times': 65,
#          'aldis': 64,
#          'super': 64,
#          'low': 63,
#          'weekly': 62,
#          'offers': 62,
#          'ok': 61,
#          'veg': 59,
#          'today': 59,
#          'bargains': 59,
#          'dublin': 58,
#          'day': 58,
#          'deals': 58,
#          'quite': 58,
#          'usual': 56,
#          'check': 56,
#          'cheaper': 55,
#          'handy': 54,
#          'checkout': 54,
#          'local': 53,
#          'vegetables': 52,
#          'amazing': 52,
#          'way': 52,
#          'recommend': 51,
#          'efficient': 51,
#          'needed': 51,
#          'favourite': 51,
#          'available': 50,
#          'queues': 50,
#          'say': 50,
#          'meat': 49,
#          'know': 49,
#          'use': 48,
#          'looking': 48,
#          'going': 48,
#          'affordable': 47,
#          'im': 47,
#          'want': 47,
#          'little': 47,
#          'went': 47,
#          'wide': 46,
#          'needs': 46,
#          'product': 46,
#          'security': 45,
#          'spacious': 44,
#          'space': 44,
#          'work': 44,
#          'didnt': 43,
#          'help': 42,
#          'area': 42,
#          'queue': 42,
#          'week': 41,
#          'fast': 41,
#          'brilliant': 41,
#          'rude': 41,
#          'large': 41,
#          'fantastic': 41,
#          'bad': 40,
#          'visit': 40,
#          'usually': 40,
#          'happy': 39,
#          'home': 39,
#          'layout': 39,
#          'tidy': 38,
#          'checkouts': 37,
#          'poor': 37,
#          'tesco': 37,
#          'shops': 36,
#          'middle': 34,
#          'convenient': 34,
#          'manager': 34,
#          'think': 34,
#          'underground': 34,
#          'ireland': 33,
#          'make': 33,
#          'supermarkets': 33,
#          'trolley': 33,
#          'options': 32,
#          'foods': 32,
#          'right': 32,
#          'irish': 31,
#          'ive': 31,
#          'crowded': 31,
#          'pretty': 31,
#          'told': 31,
#          'thats': 30,
#          'aisles': 30,
#          'look': 30,
#          'wine': 30,
#          'loads': 30,
#          'terenure': 30,
#          'thank': 29,
#          'section': 29,
#          'wait': 29,
#          'priced': 29,
#          'branch': 29,
#          'high': 29,
#          'buys': 28,
#          'u': 28,
#          'standard': 28,
#          'bread': 28,
#          'compared': 28,
#          'pm': 28,
#          'hard': 28,
#          'road': 27,
#          'asked': 27,
#          'does': 27,
#          'getting': 27,
#          'used': 27,
#          'worth': 27,
#          'far': 27,
#          'especially': 27,
#          'stop': 27,
#          'waiting': 27,
#          'organized': 27,
#          'fruits': 27,
#          'cashier': 27,
#          'different': 27,
#          'doesnt': 26,
#          'definitely': 26,
#          'date': 26,
#          'did': 25,
#          'stars': 25,
#          'close': 25,
#          'cheapest': 25,
#          'thing': 25,
#          'thanks': 25,
#          'years': 25,
#          'laid': 24,
#          'seen': 24,
#          'regular': 24,
#          'offer': 24,
#          'wish': 24,
#          'outside': 24,
#          'enjoy': 24,
#          'normal': 24,
#          'said': 24,
#          'bakery': 24,
#          'number': 24,
#          'inside': 23,
#          'self': 23,
#          'sell': 23,
#          'extremely': 23,
#          'grand': 23,
#          'centre': 23,
#          'fine': 23,
#          'old': 23,
#          'near': 23,
#          'left': 23,
#          'floor': 23,
#          'decent': 23,
#          'huge': 23,
#          'street': 23,
#          'carpark': 23,
#          'minutes': 23,
#          'run': 23,
#          'sure': 22,
#          'come': 22,
#          'chicken': 22,
#          'city': 22,
#          'pay': 22,
#          'entrance': 22,
#          'hours': 22,
#          'id': 22,
#          'brand': 22,
#          'item': 22,
#          'overall': 22,
#          'wont': 22,
#          'sold': 21,
#          'away': 21,
#          'sunday': 21,
#          'packed': 21,
#          'wanted': 21,
#          'feel': 21,
#          'covid': 21,
#          'ask': 21,
#          'problem': 20,
#          'polite': 20,
#          'having': 20,
#          'expect': 20,
#          'reasonably': 20,
#          'cheerful': 20,
#          'bright': 20,
#          'bray': 20,
#          'meats': 19,
#          'discount': 19,
#          'member': 19,
#          'spaces': 19,
#          'doing': 19,
#          'gone': 19,
#          'household': 19,
#          'opened': 19,
#          'quickly': 19,
#          'trolleys': 19,
#          'isle': 18,
#          'short': 18,
#          'aisle': 18,
#          'expensive': 18,
#          'cost': 18,
#          'morning': 18,
#          'bought': 18,
#          'theres': 18,
#          'opening': 18,
#          'plus': 18,
#          'quiet': 18,
#          'building': 18,
#          'bags': 18,
#          'brands': 18,
#          'coolock': 18,
#          'evening': 18,
#          'highly': 17,
#          'days': 17,
#          'specials': 17,
#          'management': 17,
#          'trying': 17,
#          'youre': 17,
#          'dirty': 17,
#          'makes': 17,
#          'located': 17,
#          'daily': 17,
#          'competitive': 17,
#          'n': 17,
#          'ample': 17,
#          'safe': 17,
#          'perfect': 17,
#          'market': 17,
#          'cash': 17,
#          'weeks': 17,
#          'closed': 16,
#          'working': 16,
#          'pack': 16,
#          'tell': 16,
#          'star': 16,
#          'distancing': 16,
#          'guy': 16,
#          'door': 16,
#          'pleasure': 16,
#          'center': 16,
#          'wines': 16,
#          'bargain': 16,
#          'particular': 16,
#          'social': 16,
#          'prefer': 16,
#          'cashiers': 16,
#          'try': 16,
#          'euro': 16,
#          'came': 16,
#          'christmas': 16,
#          'limited': 16,
#          'generally': 15,
#          'walk': 15,
#          's': 15,
#          'absolutely': 15,
#          'eat': 15,
#          'live': 15,
#          'end': 15,
#          'half': 15,
#          'understand': 15,
#          'fair': 15,
#          'year': 15,
#          'tight': 15,
#          'baby': 15,
#          'organised': 15,
#          'rush': 15,
#          'bag': 15,
#          'bigger': 15,
#          'wouldnt': 15,
#          'family': 15,
#          'disappointed': 15,
#          'wrong': 15,
#          'change': 15,
#          'ashbourne': 15,
#          'shoppers': 14,
#          'helpfull': 14,
#          'looked': 14,
#          'extra': 14,
#          'save': 14,
#          'care': 14,
#          'review': 14,
#          'general': 14,
#          'beautiful': 14,
#          'packing': 14,
#          'wonderful': 14,
#          'house': 14,
#          'kind': 14,
#          'isnt': 14,
#          'lines': 14,
#          'luas': 14,
#          'beat': 14,
#          'sandyford': 14,
#          'frozen': 13,
#          'tools': 13,
#          'spot': 13,
#          'making': 13,
#          'probably': 13,
#          'main': 13,
#          'disabled': 13,
#          'card': 13,
#          'milk': 13,
#          'felt': 13,
#          'missing': 13,
#          'access': 13,
#          'budget': 13,
#          'rest': 13,
#          'messy': 13,
#          'basket': 13,
#          'unfortunately': 13,
#          'spend': 13,
#          'size': 13,
#          'clothes': 13,
#          'able': 13,
#          'recently': 13,
#          'theyre': 12,
#          'looks': 12,
#          'coming': 12,
#          'vegan': 12,
#          'choose': 12,
#          'plastic': 12,
#          'terrible': 12,
#          'hope': 12,
#          'deal': 12,
#          'despite': 12,
#          'masks': 12,
#          'shopped': 12,
#          'leave': 12,
#          'early': 12,
#          'cool': 12,
#          'alot': 12,
#          'town': 12,
#          'smaller': 12,
#          'places': 12,
#          'professional': 12,
#          'person': 12,
#          'roof': 12,
#          'shelf': 12,
#          'issue': 12,
#          'wasnt': 12,
#          'buying': 12,
#          'basic': 12,
#          'average': 12,
#          'life': 12,
#          'bus': 12,
#          'th': 12,
#          'dunnes': 12,
#          'slow': 12,
#          'sallynoggin': 12,
#          'ready': 11,
#          'popular': 11,
#          'east': 11,
#          'particularly': 11,
#          'willing': 11,
#          'fan': 11,
#          'facilities': 11,
#          'fact': 11,
#          'man': 11,
#          'reason': 11,
#          'wearing': 11,
#          'veggies': 11,
#          'staffs': 11,
#          'queuing': 11,
#          'line': 11,
#          'maybe': 11,
#          'problems': 11,
#          'traffic': 11,
#          'receipt': 11,
#          'recommended': 11,
#          'untidy': 11,
#          'sells': 11,
#          'baskets': 11,
#          'lost': 11,
#          'levels': 11,
#          'savings': 11})

# %%
# Aldi custom stop words
sorted_words = [word for word, freq in word_freq1.most_common()]

horizontal_words = ', '.join(sorted_words)
print(horizontal_words)
# Out:
# good, great, staff, aldi, shop, store, prices, value, friendly, nice, shopping, parking, place, products, food, helpful, quality, love, service, cheap, selection, price, like, best, clean, excellent, need, just, supermarket, stocked, items, time, busy, lovely, fresh, really, lidl, stock, easy, dont, big, money, variety, people, range, better, free, customer, lots, bit, plenty, car, experience, lot, stores, tills, buy, got, new, groceries, fruit, till, things, goods, reasonable, choice, open, special, location, long, park, shelves, customers, quick, small, pleasant, grocery, produce, stuff, times, aldis, super, low, weekly, offers, ok, veg, today, bargains, dublin, day, deals, quite, usual, check, cheaper, handy, checkout, local, vegetables, amazing, way, recommend, efficient, needed, favourite, available, queues, say, meat, know, use, looking, going, affordable, im, want, little, went, wide, needs, product, security, spacious, space, work, didnt, help, area, queue, week, fast, brilliant, rude, large, fantastic, bad, visit, usually, happy, home, layout, tidy, checkouts, poor, tesco, shops, middle, convenient, manager, think, underground, ireland, make, supermarkets, trolley, options, foods, right, irish, ive, crowded, pretty, told, thats, aisles, look, wine, loads, terenure, thank, section, wait, priced, branch, high, buys, u, standard, bread, compared, pm, hard, road, asked, does, getting, used, worth, far, especially, stop, waiting, organized, fruits, cashier, different, doesnt, definitely, date, did, stars, close, cheapest, thing, thanks, years, laid, seen, regular, offer, wish, outside, enjoy, normal, said, bakery, number, inside, self, sell, extremely, grand, centre, fine, old, near, left, floor, decent, huge, street, carpark, minutes, run, sure, come, chicken, city, pay, entrance, hours, id, brand, item, overall, wont, sold, away, sunday, packed, wanted, feel, covid, ask, problem, polite, having, expect, reasonably, cheerful, bright, bray, meats, discount, member, spaces, doing, gone, household, opened, quickly, trolleys, isle, short, aisle, expensive, cost, morning, bought, theres, opening, plus, quiet, building, bags, brands, coolock, evening, highly, days, specials, management, trying, youre, dirty, makes, located, daily, competitive, n, ample, safe, perfect, market, cash, weeks, closed, working, pack, tell, star, distancing, guy, door, pleasure, center, wines, bargain, particular, social, prefer, cashiers, try, euro, came, christmas, limited, generally, walk, s, absolutely, eat, live, end, half, understand, fair, year, tight, baby, organised, rush, bag, bigger, wouldnt, family, disappointed, wrong, change, ashbourne, shoppers, helpfull, looked, extra, save, care, review, general, beautiful, packing, wonderful, house, kind, isnt, lines, luas, beat, sandyford, frozen, tools, spot, making, probably, main, disabled, card, milk, felt, missing, access, budget, rest, messy, basket, unfortunately, spend, size, clothes, able, recently, theyre, looks, coming, vegan, choose, plastic, terrible, hope, deal, despite, masks, shopped, leave, early, cool, alot, town, smaller, places, professional, person, roof, shelf, issue, wasnt, buying, basic, average, life, bus, th, dunnes, slow, sallynoggin, ready, popular, east, particularly, willing, fan, facilities, fact, man, reason, wearing, veggies, staffs, queuing, line, maybe, problems, traffic, receipt, recommended, untidy, sells, baskets, lost, levels, savings

# %%
#Lidl custom stop words

custom_stop_words = {'good', 'great', 'lidl', 'shop', 'maybe', 'store', 'supermarkets', 'centre', 'products', 'nice', 'shopping', 'place', 'food', 'like', 'need', 'best', 'big', 'items', 'just', 'love', 'supermarket', 'excellent', 'dont', 'really', 'people', 'new', "lovely", 'buy', 'experience', 'range', 'better', 'small', 'customer', 'got', 'lots', 'things', 'stuff', 'today', 'plenty', 'lot', 'easy', 'times', 'day', 'check', 'groceries', 'area', 'money', 'customers', 'way', 'bit', 'goods', 'location', 'bad', 'free', 'amazing', 'quite', 'dublin', 'usual', 'large', 'know', 'available', 'week', 'ok', 'weekly', 'stores', 'produce', 'super', 'went', 'lidls', 'self', 'needed', 'cheaper', 'product', 'want', 'visit', 'say', 'section', 'going', 'ireland', 'little', 'recommend', 'special', 'shops', 'pleasant', 'especially', 'didnt', 'grocery', 'work', 'wide', 'home', 'working', 'different', 'street', 'looking', 'decent', 'usually', 'local', 'pay', 'im', 'wait', 'thats', 'supermarket', 'doesnt', 'needs', 'came', 'city', 'smaller', 'cemtre', 'pretty', 'bought', 'inside', 'efficient', 'ive', 'huge', 'quickly', 'does', 'happy', 'look', 'said', 'fine', 'make', 'use', 'daily', 'brilliant', 'told', 'come', 'theres', 'extremely', 'job', 'getting', 'left', 'problem', 'missing', 'seen', 'fantastic', 'bigger', 'did', 'poor', 'right', 'expect', 'compared', 'wrong', 'thank', 'road', 'standard', 'sure', 'minutes', 'hard', 'normal', 'cash', 'terrible', 'think', 'waiting', 'floor', 'worst', 'thing', 'branch', 'market', 'hours', 'man', 'worth', 'foods', 'u', 'perfect', 'kind', 'thomas', 'ask', 'wont', 'favourite', 'outside', 'grand', 'loads', 'early', 'spaces', 'larger', 'makes', 'days', 'highly', 'typical', 'recently', 'access', 'priced', 'high', 'run', 'generally', 'horrible', 'asked', 'closed', 'disappointed', 'point', 'late', 'extra', 'wish', 'doing', 'lack', 'opening', 'st', 'far', 'gone', 'regular', 'morning', 'years', 'weekend', 'thanks', 'laid', 'beautiful', 'item', 'change', 'used', 'card', 'kept', 'outs', 'person', 'away', 'wanted', 'tools', 'middle', 'avoid', 'approx', 'trying', 'lady', 'able', 'sell', 'room', 'size', 'located', 'wasnt', 'youre', 'sold'}

# %%
custom_stop_words = {'good', 'great', 'aldi', 'shop', 'store', 'nice', 'shopping', 'place', 'products', 'food', 'love', 
                     'like', 'best', 'excellent', 'need', 'just', 'supermarket', 'items', 'really', 'dont', 'big', 'money', 
                     'better', 'free', 'customer', 'lots', 'bit', 'experience', 'lot', 'stores', 'buy', 'got', 'new', 'things', 
                     'goods', 'special','customers', 'grocery', 'stuff', 'times', 'aldis', 'super', 'weekly', 'ok', 
                     'today', 'dublin', 'day', 'quite', 'usual', 'check', 'cheaper', 'amazing', 'way', "recommend", "needed", "favourite", 
                     "available", "say", "know", "use", "looking", "going", "im", "want", "little", "went", "needs", "product", "work", "didnt", "area", "week",
                     "brilliant", "fantastic", "bad", "visit", "usually", "happy", "home", "shops", "middle", "think", 
                     "underground", "ireland", "make", "supermarkets", "foods", "right", "ive", "pretty", "told", "thats", "look", "loads", 
                     "thank", "section", "wait", "priced", "branch", "high", "buys", "looks", "shoppers", "u", "compared", "hard", "road", "asked", "does", "getting", "used", "worth", "far", "especially", "stop", 
                     "different", "doesnt", "definitely", "did", "stars", "cheapest", "thing", "thanks", "years", "laid", "seen", 
                     "wish", "outside", "enjoy", "normal", "said", "number", "self", "extremely", "grand", "centre", "fine", "near", "left", "decent", "huge", "street", 
                     "minutes", "run", "sure", "come", "city", "pay", "id", "item", "overall", "wont", "sold", "away", "wanted", "feel", "covid", 
                     "ask", "problem", "having", "expect", "reasonably", "bright", "doing", "gone", "household",
                     "bought", "theres", "plus", "highly", "days", "trying", "youre", "makes", "located", "daily", "competitive", "n", "perfect", "cash", "weeks", "closed", "working", "pack", 
                     "tell", "star", "distancing", "guy", "pleasure", "center", "theyre" "bargain", "particular", "social", "prefer", "try", "euro", "came"}

# %%
all_stop_words = custom_stop_words.union(set(new_stop_words))

# %%
def preprocess_text(text, all_stop_words):
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Split text into words
    words = text.split()
    # Remove stop words
    words = [word for word in words if word not in all_stop_words]
    return words

# Apply the preprocessing function to the DataFrame
df['Processed_Text_2'] = df['Review Text'].apply(lambda x: preprocess_text(x, all_stop_words))

# %%
# Remove rows where 'Processed_Text_2' is an empty list
df = df[df['Processed_Text_2'].apply(lambda x: len(x) > 0)]

# Optionally reset the index
df.reset_index(drop=True, inplace=True)

# %%
df = df.drop(['Review Text', 'Store', 'Processed Text', 'Processed_Text_1'], axis=1)

# %%
df.rename(columns={'Processed_Text_2': 'Cleaned Text'}, inplace=True)

# %%
df
# Out:
#      Sentiment Label  Sentiment Score  \
# 0           positive           0.8271
# 1           positive           0.8442
# 2           positive           0.6956
# 3           positive           0.9974
# 4            neutral           0.0320
# ...              ...              ...
# 3699         neutral           0.0000
# 3700        negative          -0.4588
# 3701        positive           0.2960
# 3702        negative          -0.5095
# 3703        positive           0.4404
#
#                                            Cleaned Text
# 0     [generally, reasonable, prices, value, options...
# 1     [selection, fresh, vegetables, meats, frozen, ...
# 2     [discount, theyre, stocked, fresh, stocked, li...
# 3                     [wide, range, affordable, prices]
# 4                               [quality, meat, inside]
# ...                                                 ...
# 3699                            [ample, parking, space]
# 3700                                       [till, rude]
# 3701                                            [value]
# 3702                                             [rude]
# 3703                                          [produce]
#
# [3704 rows x 3 columns]

# %%
df.to_csv('/Users/esthercorcoran/Desktop/Thesis/Aldi/Preprocessed Aldi.csv', index=False)

# %%
### or 

df.to_csv('/Users/esthercorcoran/Desktop/Thesis/Lidl/Preprocessed Lidl.csv', index=False)

# %%
### Data analysis

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np

# %%
df = pd.read_csv('/Users/esthercorcoran/Desktop/Thesis/Aldi/Preprocessed Aldi.csv')

### or 

 = pd.read_csv('/Users/esthercorcoran/Desktop/Thesis/Lidl/Preprocessed Lidl.csv')

# %%
# clean text data 
def clean_text(text_list):
    if isinstance(text_list, list):
        # Join the words in the list into a single string separated by commas
        return ', '.join(text_list)
    return text_list  # If it's not a list, return the text as it is

df['Cleaned Text'] = df['Cleaned Text'].apply(clean_text)

# %%
sentiment_counts = df['Sentiment Label'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', colors=['lightblue', 'lightpink', 'lightgreen'])
plt.title('Distribution of Sentiment Labels for Aldi Reviews')
plt.show()

# %%
# positive analysis

# %%
positive_df = df[df['Sentiment Label'] == 'positive']

# %%
### positive topics 

import numpy as np

vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
text_data = positive_df['Cleaned Text'].apply(lambda x: ' '.join(eval(x)))
X = vectorizer.fit_transform(text_data)

# Fit LDA model
lda = LatentDirichletAllocation(n_components=3, random_state=42)
lda.fit(X)

def plot_topics(lda_model, vectorizer, n_top_words=5, n_topics=3, figsize=(12, 8)):
    feature_names = vectorizer.get_feature_names_out()
    colors = plt.cm.get_cmap('Set3', n_top_words)  # Using Set3 colormap for pleasant colors

    fig, axes = plt.subplots(1, n_topics, figsize=figsize, sharey=True)
    plt.subplots_adjust(wspace=0.4)

    for topic_idx, topic in enumerate(lda_model.components_):
        top_words_indices = topic.argsort()[:-n_top_words - 1:-1]
        top_words = [feature_names[i] for i in top_words_indices]
        weights = topic[top_words_indices]
        bar_colors = colors(np.arange(n_top_words))

        ax = axes[topic_idx]
        ax.barh(top_words, weights, color=bar_colors, edgecolor='black')
        ax.set_title(f'Topic #{topic_idx + 1}', fontsize=14)
        ax.invert_yaxis()  # Invert y-axis to have the most relevant words at the top
        ax.set_xlabel('Weight', fontsize=12)

    plt.tight_layout()
    plt.show()

plot_topics(lda, vectorizer, n_top_words=5, n_topics=3, figsize=(15, 5))

# %%
import pandas as pd
import seaborn as sns

# %%
### unigrams

text_data = positive_df['Cleaned Text'].apply(lambda x: ' '.join(eval(x)))

vectorizer = CountVectorizer(ngram_range=(1, 1))
X = vectorizer.fit_transform(text_data)

unigram_freq = pd.DataFrame({
    'unigram': vectorizer.get_feature_names_out(),
    'frequency': X.toarray().sum(axis=0)
})

# sort
top_unigrams = unigram_freq.sort_values(by='frequency', ascending=False).head(20)
top_unigrams = top_unigrams.reset_index(drop=True)

# plot
sns.set(style="whitegrid")

plt.figure(figsize=(12, 8))  # Specify the figure size
barplot = sns.barplot(x='frequency', y='unigram', data=top_unigrams, palette="pastel")

plt.title('Top 20 Unigrams for Positive Reviews')
plt.xlabel('Frequency')
plt.ylabel('Unigrams')

plt.show()

# %%
### bigram

text_data = positive_df['Cleaned Text'].apply(lambda x: ' '.join(eval(x)))

vectorizer = CountVectorizer(ngram_range=(2, 2))
X = vectorizer.fit_transform(text_data)

bigram_freq = pd.DataFrame({
    'bigram': vectorizer.get_feature_names_out(),
    'frequency': X.toarray().sum(axis=0)
})

top_bigrams = bigram_freq.sort_values(by='frequency', ascending=False).head(20)

top_bigrams = top_bigrams.reset_index(drop=True)

### plot 
sns.set(style="whitegrid")

plt.figure(figsize=(12, 8))  # Specify the figure size
barplot = sns.barplot(x='frequency', y='bigram', data=top_bigrams, palette="pastel")

plt.title('Top 20 Bigrams for Positive Reviews')
plt.xlabel('Frequency')
plt.ylabel('Bigrams')
plt.show()

# %%
### negative analysis

# %%
### negative topics 

vectorizer = CountVectorizer(max_df=0.95, min_df=2, stop_words='english')
text_data = negative_df['Cleaned Text'].apply(lambda x: ' '.join(eval(x)))
X = vectorizer.fit_transform(text_data)

lda = LatentDirichletAllocation(n_components=3, random_state=42)
lda.fit(X)

# plot
def plot_topics(lda_model, vectorizer, n_top_words=5, n_topics=3, figsize=(12, 8)):
    feature_names = vectorizer.get_feature_names_out()
    colors = plt.cm.get_cmap('Set3', n_top_words)  # Using Set3 colormap for pleasant colors

    fig, axes = plt.subplots(1, n_topics, figsize=figsize, sharey=True)
    plt.subplots_adjust(wspace=0.4)

    for topic_idx, topic in enumerate(lda_model.components_):
        top_words_indices = topic.argsort()[:-n_top_words - 1:-1]
        top_words = [feature_names[i] for i in top_words_indices]
        weights = topic[top_words_indices]
        bar_colors = colors(np.arange(n_top_words))

        ax = axes[topic_idx]
        ax.barh(top_words, weights, color=bar_colors, edgecolor='black')
        ax.set_title(f'Topic #{topic_idx + 1}', fontsize=14)
        ax.invert_yaxis()  # Invert y-axis to have the most relevant words at the top
        ax.set_xlabel('Weight', fontsize=12)

    plt.tight_layout()
    plt.show()

plot_topics(lda, vectorizer, n_top_words=5, n_topics=3, figsize=(15, 5))

# %%
### unigrams

text_data3 = negative_df['Cleaned Text'].apply(lambda x: ' '.join(eval(x)))
vectorizer = CountVectorizer(ngram_range=(1, 1))
X = vectorizer.fit_transform(text_data3)

unigram_freq = pd.DataFrame({
    'unigram': vectorizer.get_feature_names_out(),
    'frequency': X.toarray().sum(axis=0)
})

top_unigrams3 = unigram_freq.sort_values(by='frequency', ascending=False).head(20)

# plot
plt.figure(figsize=(10, 8))
plt.barh(top_unigrams3['unigram'], top_unigrams3['frequency'], color=plt.cm.Pastel1.colors)
plt.xlabel('Frequency')
plt.ylabel('Unigrams')
plt.title('Top 20 Unigrams for Aldi Negative Reviews')
plt.gca().invert_yaxis()
plt

# %%
# bigram

text_data3 = negative_df['Cleaned Text'].apply(lambda x: ' '.join(eval(x)))
vectorizer = CountVectorizer(ngram_range=(2, 2))
X = vectorizer.fit_transform(text_data3)

bigram_freq = pd.DataFrame({
    'bigram': vectorizer.get_feature_names_out(),
    'frequency': X.toarray().sum(axis=0)
})

top_bigrams3 = bigram_freq.sort_values(by='frequency', ascending=False).head(20)

# plot
plt.figure(figsize=(10, 8))
plt.barh(top_bigrams3['bigram'], top_bigrams3['frequency'], color=plt.cm.Pastel1.colors)
plt.xlabel('Frequency')
plt.ylabel('Bigrams')
plt.title('Top 20 Bigrams for Aldi Negative Reviews')
plt.gca().invert_yaxis()
plt.show()

# %%
### clustering

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Cleaned Text'].apply(lambda x: ' '.join(eval(x))))

# %%
from sklearn.cluster import KMeans
### k means clustering
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(tfidf_matrix)

# %%
for cluster in range(optimal_k):
    cluster_data = df[df['Cluster'] == cluster]
    print(f"Cluster {cluster}:\n")
    print(cluster_data['Cleaned Text'].apply(lambda x: ' '.join(eval(x))).head(10))
    print("\n")

# %%
from collections import Counter

# change cluster number when needed


cluster_3_data = df[df['Cluster'] == 3]

# clean
def clean_and_tokenize(text):
    # Remove punctuation and convert to lowercase
    text = re.sub(r'[^\w\s]', '', text).lower()
    # Tokenize the text
    tokens = text.split()
    return tokens

all_words3 = [token for tokens in cluster_3_data['Cleaned Text'].apply(clean_and_tokenize) for token in tokens]

# count most common words
common_words_3 = Counter(all_words3).most_common()

filtered_words = [(word, count) for word, count in common_words_3 if count > 7]

if filtered_words:
    words, counts = zip(*filtered_words)
else:
    words, counts = [], []

# plot
plt.figure(figsize=(12, 8))
plt.barh(words, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Words')
plt.title('Common Words in Quality Emphasisers Cluster')
plt.gca().invert_yaxis()
plt.show()

# %%
# change key word when needed
# co occurance analysis 
def clean_and_tokenize(text):
    text = re.sub(r'[^\w\s]', '', text).lower()
    tokens = text.split()
    return tokens

# extract sentences containing the word "Lidl"
lidl_sentences = cluster_0_data[cluster_0_data['Cleaned Text'].str.contains('lidl', case=False)]

co_occurring_words = []


for index, row in lidl_sentences.iterrows():
    text = row['Cleaned Text']
    tokens = clean_and_tokenize(text)
    
    if 'lidl' in tokens:
        co_occurring_words.extend(tokens)

co_occurring_words = [word for word in co_occurring_words if word != 'lidl']
co_occurrence_counts = Counter(co_occurring_words)
top_co_occurring_words = co_occurrence_counts.most_common(20)
words, counts = zip(*top_co_occurring_words)

# plot
plt.figure(figsize=(12, 8))
plt.barh(words, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Words')
plt.title('"Lidl" Co-occurring Words in Lidl Comparers Cluster')
plt.gca().invert_yaxis()  # To display the highest counts on top
plt.show()
